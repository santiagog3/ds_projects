# %%
import pandas as pd

# %%
url = 'https://cdn.buenosaires.gob.ar/datosabiertos/datasets/salud/casos-covid-19/casos_covid19.csv'
#data = pd.read_csv('casos_covid19.csv')
data = pd.read_csv(url)
# Out:
# /home/santiago/anaconda3/envs/dhdsblend/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3156: DtypeWarning: Columns (10,11,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.tail(5)
# Out:
#          numero_de_caso        fecha_apertura_snvs         fecha_toma_muestra  \
# 1938705         7086309  31JAN2021:00:00:00.000000  31JAN2021:00:00:00.000000
# 1938706         7086310  31JAN2021:00:00:00.000000  31JAN2021:00:00:00.000000
# 1938707         7086311  31JAN2021:00:00:00.000000  31JAN2021:00:00:00.000000
# 1938708         7086312  31JAN2021:00:00:00.000000  31JAN2021:00:00:00.000000
# 1938709         7086313  31JAN2021:00:00:00.000000  31JAN2021:00:00:00.000000
#
#                fecha_clasificacion     provincia     barrio  comuna  \
# 1938705  31JAN2021:00:00:00.000000          CABA   RECOLETA     2.0
# 1938706  31JAN2021:00:00:00.000000          CABA      NUÑEZ    13.0
# 1938707  31JAN2021:00:00:00.000000      Misiones        NaN     NaN
# 1938708  31JAN2021:00:00:00.000000  Buenos Aires        NaN     NaN
# 1938709  31JAN2021:00:00:00.000000          CABA  MONSERRAT     1.0
#
#             genero  edad clasificacion fecha_fallecimiento fallecido  \
# ...

# %%
data[data['provincia']=='CABA']
# Out:
#          numero_de_caso        fecha_apertura_snvs         fecha_toma_muestra  \
# 0               2603259  14SEP2020:00:00:00.000000  14SEP2020:00:00:00.000000
# 1               2603403  14SEP2020:00:00:00.000000  14SEP2020:00:00:00.000000
# 2               2603962  14SEP2020:00:00:00.000000  11SEP2020:00:00:00.000000
# 5               2605953  14SEP2020:00:00:00.000000  12SEP2020:00:00:00.000000
# 6               2606175  14SEP2020:00:00:00.000000  14SEP2020:00:00:00.000000
# ...                 ...                        ...                        ...
# 1391972         3345045  12OCT2020:00:00:00.000000  10OCT2020:00:00:00.000000
# 1391973         3345048  12OCT2020:00:00:00.000000  10OCT2020:00:00:00.000000
# 1391979         3351843  12OCT2020:00:00:00.000000  11OCT2020:00:00:00.000000
# 1391981         3351857  12OCT2020:00:00:00.000000  12OCT2020:00:00:00.000000
# 1391982         3351859  12OCT2020:00:00:00.000000  11OCT2020:00:00:00.000000
#
# ...

# %%
data.fallecido.value_counts()
# Out:
# si    9944
# Name: fallecido, dtype: int64

# %%
data.fecha_alta.isnull().mean()
# Out:
# 0.9432465556406459
